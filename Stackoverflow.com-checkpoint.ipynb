# %% [markdown]
# ## Scraping all the questions and other details from stackoverflow.

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# Load the URL
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'python'
query_filter = 'Votes'
url = f"{base_url}{tag}?tab={query_filter}"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all elements with the class 's-post-summary' or 'js-post-summary'
    post_summaries = soup.find_all(class_=['s-post-summary'])
    
    # Iterate over each post summary
    for post_summary in post_summaries:
        # Split the text of post summary by newline character
        lines = post_summary.text.split("\n")
        
        # Filter out empty lines
        lines = [line.strip() for line in lines if line.strip()]
        
        # Print each line
        for line in lines:
            print(line)
        
        # Add a separator for better readability
        print('-' * 50)
else:
    print("Failed to fetch the page")
# Out:
# 12878
# votes
# 50
# answers
# 3.3m
# views
# What does the "yield" keyword do in Python?
# What functionality does the 'yield' keyword in Python provide?
# For example, I'm trying to understand this code1:
# def _get_child_candidates(self, distance, min_dist, max_dist):
# if self._leftchild ...
# pythoniteratorgeneratoryield
# Alex. S.
# 145k
# asked Oct 23, 2008 at 22:21
# --------------------------------------------------
# 8196
# votes
# 46
# answers
# 4.6m
# views
# What does if __name__ == "__main__": do?
# What does this do, and why should one include the if statement?
# if __name__ == "__main__":
# print("Hello, World!")
# If you are trying to close a question where someone should be ...
# pythonnamespacesprogram-entry-pointpython-moduleidioms
# Devoted
# 180k
# asked Jan 7, 2009 at 4:11
# --------------------------------------------------
# 7901
# votes
# 32
# answers
# 2.9m
# views
# Does Python have a ternary conditional operator?
# Is there a ternary conditional operator in Python?
# pythonoperatorsconditional-operator
# Devoted
# 180k
# asked Dec 27, 2008 at 8:32
# --------------------------------------------------
# 7364
# votes
# 25
# answers
# 1.2m
# views
# What are metaclasses in Python?
# What are metaclasses? What are they used for?
# pythonoopmetaclasspython-classpython-datamodel
# Bite code
# 587k
# asked Sep 19, 2008 at 6:10
# --------------------------------------------------
# 7123
# votes
# 41
# answers
# 5.4m
# views
# How do I check whether a file exists without exceptions?
# How do I check whether a file exists or not, without using the try statement?
# pythonfilefile-exists
# spence91
# 78.4k
# asked Sep 17, 2008 at 12:55
# --------------------------------------------------
# 6917
# votes
# 43
# answers
# 3.3m
# views
# How do I merge two dictionaries in a single expression in Python?
# I want to merge two dictionaries into a new dictionary.
# x = {'a': 1, 'b': 2}
# y = {'b': 3, 'c': 4}
# z = merge(x, y)
# >>> z
# {'a': 1, 'b': 3, 'c': 4}
# Whenever a key k is present in both ...
# pythondictionarymerge
# Carl Meyer
# 124k
# asked Sep 2, 2008 at 7:44
# --------------------------------------------------
# 6111
# votes
# 66
# answers
# 4.7m
# views
# How do I execute a program or call a system command?
# How do I call an external command within Python as if I had typed it in a shell or command prompt?
# pythonshellterminalsubprocesscommand
# freshWoWer
# 62.9k
# asked Sep 18, 2008 at 1:35
# --------------------------------------------------
# 5643
# votes
# 27
# answers
# 3.7m
# views
# How do I create a directory, and any missing parent directories?
# How do I create a directory at a given path, and also create any missing parent directories along that path? For example, the Bash command mkdir -p /path/to/nested/directory does this.
# pythonexceptionpathdirectoryoperating-system
# Parand
# 104k
# asked Nov 7, 2008 at 18:56
# --------------------------------------------------
# 5421
# votes
# 29
# answers
# 4.4m
# views
# How to access the index value in a 'for' loop?
# How do I access the index while iterating over a sequence with a for loop?
# xs = [8, 23, 45]
# for x in xs:
# print("item #{} = {}".format(index, x))
# Desired output:
# item #1 = 8
# item #2 = ...
# pythonloopslist
# Joan Venge
# 323k
# asked Feb 6, 2009 at 22:47
# --------------------------------------------------
# 5317
# votes
# 32
# answers
# 4.3m
# views
# How do I make a flat list out of a list of lists?
# I have a list of lists like
# [
# [1, 2, 3],
# [4, 5, 6],
# [7],
# [8, 9]
# ]
# How can I flatten it to get [1, 2, 3, 4, 5, 6, 7, 8, 9]?
# If your list of lists comes from a nested list ...
# pythonlistmultidimensional-arrayflatten
# Emma
# 54k
# asked Jun 4, 2009 at 20:30
# --------------------------------------------------
# 4641
# votes
# 36
# answers
# 1.1m
# views
# What is the difference between @staticmethod and @classmethod in Python?
# What is the difference between a method decorated with @staticmethod and one decorated with @classmethod?
# pythonoopstatic-methodspython-decoratorsclass-method
# Daryl Spitzer
# 146k
# asked Sep 25, 2008 at 21:01
# --------------------------------------------------
# 4583
# votes
# 38
# answers
# 3.0m
# views
# How slicing in Python works
# How does Python's slice notation work? That is: when I write code like a[x:y:z], a[:], a[::2] etc., how can I understand which elements end up in the slice?
# See Why are slice and range upper-bound ...
# pythonslicesequence
# Simon
# 79.6k
# asked Feb 3, 2009 at 22:31
# --------------------------------------------------
# 4385
# votes
# 46
# answers
# 6.3m
# views
# How to find the index for a given item in a list?
# Given a list ["foo", "bar", "baz"] and an item in the list "bar", how do I get its index 1?
# pythonlistindexing
# Eugene M
# 48.2k
# asked Oct 7, 2008 at 1:39
# --------------------------------------------------
# 4304
# votes
# 17
# answers
# 5.8m
# views
# Iterating over dictionaries using 'for' loops
# d = {'x': 1, 'y': 2, 'z': 3}
# for key in d:
# print(key, 'corresponds to', d[key])
# How does Python recognize that it needs only to read the key from the dictionary? Is key a special keyword, or is ...
# pythondictionary
# TopChef
# 44.8k
# asked Jul 20, 2010 at 22:27
# --------------------------------------------------
# 4075
# votes
# 34
# answers
# 7.3m
# views
# How can I iterate over rows in a Pandas DataFrame?
# I have a pandas dataframe, df:
# c1   c2
# 0  10  100
# 1  11  110
# 2  12  120
# How do I iterate over the rows of this dataframe? For every row, I want to access its elements (values in cells) by the name ...
# pythonpandasdataframeloops
# Roman
# 128k
# asked May 10, 2013 at 7:04
# --------------------------------------------------
# 3948
# votes
# 25
# answers
# 4.1m
# views
# How to use a global variable in a function?
# How do I create or use a global variable inside a function?
# How do I use a global variable that was defined in one function inside other functions?
# Failing to use the global keyword where appropriate ...
# pythonglobal-variablesscope
# user46646
# 156k
# asked Jan 8, 2009 at 5:45
# --------------------------------------------------
# 3853
# votes
# 54
# answers
# 4.3m
# views
# How do I get the current time in Python?
# How do I get the current time in Python?
# pythondatetimetime
# user46646
# 156k
# asked Jan 6, 2009 at 4:54
# --------------------------------------------------
# 3823
# votes
# 6
# answers
# 1.5m
# views
# How to catch multiple exceptions in one line? (in the "except" block)
# I know that I can do:
# try:
# # do something that may fail
# except:
# # do this if ANYTHING goes wrong
# I can also do this:
# try:
# # do something that may fail
# except IDontLikeYouException:
# # ...
# pythonexception
# inspectorG4dget
# 112k
# asked Jun 24, 2011 at 15:55
# --------------------------------------------------
# 3793
# votes
# 21
# answers
# 3.7m
# views
# How to copy files
# How do I copy a file in Python?
# pythonfilecopyfilesystemsfile-copying
# Matt
# 86.1k
# asked Sep 23, 2008 at 19:23
# --------------------------------------------------
# 3751
# votes
# 23
# answers
# 5.0m
# views
# Convert bytes to a string in Python 3
# I captured the standard output of an external program into a bytes object:
# >>> from subprocess import *
# >>> stdout = Popen(['ls', '-l'], stdout=PIPE).communicate()[0]
# >>> ...
# pythonstringpython-3.x
# Tomas Sedovic
# 43.4k
# asked Mar 3, 2009 at 12:23
# --------------------------------------------------
# 3730
# votes
# 14
# answers
# 2.4m
# views
# What is __init__.py for?
# What is __init__.py for in a Python source directory?
# pythonmodulepackagepython-packaging
# Mat
# 84.1k
# asked Jan 15, 2009 at 20:09
# --------------------------------------------------
# 3689
# votes
# 28
# answers
# 983k
# views
# What is the difference between __str__ and __repr__?
# What is the difference between __str__ and __repr__ in Python?
# pythonmagic-methodsrepr
# Casebash
# 116k
# asked Sep 17, 2009 at 4:27
# --------------------------------------------------
# 3587
# votes
# 10
# answers
# 6.7m
# views
# Does Python have a string 'contains' substring method?
# I'm looking for a string.contains or string.indexof method in Python.
# I want to do:
# if not somestring.contains("blah"):
# continue
# pythonstringsubstringcontains
# Blankman
# 263k
# asked Aug 9, 2010 at 2:52
# --------------------------------------------------
# 3523
# votes
# 21
# answers
# 5.3m
# views
# How can I add new keys to a dictionary?
# How do I add a new key to an existing dictionary? It doesn't have an .add() method.
# pythondictionarylookup
# lfaraone
# 50.1k
# asked Jun 21, 2009 at 22:07
# --------------------------------------------------
# 3504
# votes
# 17
# answers
# 6.4m
# views
# How do I select rows from a DataFrame based on column values?
# How can I select rows from a DataFrame based on values in some column in Pandas?
# In SQL, I would use:
# SELECT *
# FROM table
# WHERE column_name = some_value
# pythonpandasdataframe
# szli
# 38k
# asked Jun 12, 2013 at 17:42
# --------------------------------------------------
# 3466
# votes
# 21
# answers
# 8.2m
# views
# How do I list all files of a directory?
# How can I list all files of a directory in Python and add them to a list?
# pythondirectory
# duhhunjonn
# 45.2k
# asked Jul 8, 2010 at 19:31
# --------------------------------------------------
# 3413
# votes
# 34
# answers
# 5.3m
# views
# How do I sort a dictionary by value?
# I have a dictionary of values read from two fields in a database: a string field and a numeric field. The string field is unique, so that is the key of the dictionary.
# I can sort on the keys, but how ...
# pythonsortingdictionary
# Gern Blanston
# 42.5k
# asked Mar 5, 2009 at 0:49
# --------------------------------------------------
# 3413
# votes
# 34
# answers
# 266k
# views
# "Least Astonishment" and the Mutable Default Argument
# Anyone tinkering with Python long enough has been bitten (or torn to pieces) by the following issue:
# def foo(a=[]):
# a.append(5)
# return a
# Python novices would expect this function called with ...
# pythonlanguage-designdefault-parametersleast-astonishment
# Stefano Borini
# 141k
# asked Jul 15, 2009 at 18:00
# --------------------------------------------------
# 3379
# votes
# 28
# answers
# 1.4m
# views
# What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# What do *args and **kwargs mean in these function definitions?
# def foo(x, y, *args):
# pass
# def bar(x, y, **kwargs):
# pass
# See What do ** (double star/asterisk) and * (star/asterisk) mean in a ...
# pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# Todd
# 35.2k
# asked Aug 31, 2008 at 15:04
# --------------------------------------------------
# 3376
# votes
# 18
# answers
# 3.6m
# views
# How can I delete a file or folder in Python?
# How can I delete a file or folder in Python?
# pythonfile-iodirectorydelete-file
# Zygimantas
# 34.1k
# asked Aug 9, 2011 at 13:05
# --------------------------------------------------
# 3295
# votes
# 41
# answers
# 2.1m
# views
# How do I pass a variable by reference?
# I wrote this class for testing:
# class PassByReference:
# def __init__(self):
# self.variable = 'Original'
# self.change(self.variable)
# print(self.variable)
# def change(self, ...
# pythonreferenceparameter-passingpass-by-reference
# David Sykes
# 49.1k
# asked Jun 12, 2009 at 10:23
# --------------------------------------------------
# 3289
# votes
# 24
# answers
# 2.2m
# views
# How do I clone a list so that it doesn't change unexpectedly after assignment?
# While using new_list = my_list, any modifications to new_list changes my_list every time. Why is this, and how can I clone or copy the list to prevent it?
# pythonlistclonemutable
# aF.
# 65.8k
# asked Apr 10, 2010 at 8:49
# --------------------------------------------------
# 3243
# votes
# 17
# answers
# 3.0m
# views
# How can I access environment variables in Python?
# How can I get the value of an environment variable in Python?
# pythonenvironment-variables
# Amit Yadav
# 33.4k
# asked Feb 5, 2011 at 13:03
# --------------------------------------------------
# 3238
# votes
# 31
# answers
# 4.4m
# views
# How do I concatenate two lists in Python?
# How do I concatenate two lists in Python?
# Example:
# listone = [1, 2, 3]
# listtwo = [4, 5, 6]
# Expected outcome:
# >>> joinedlist
# [1, 2, 3, 4, 5, 6]
# pythonlistconcatenation
# y2k
# 65.7k
# asked Nov 12, 2009 at 7:04
# --------------------------------------------------
# 3227
# votes
# 27
# answers
# 4.8m
# views
# How do I check if a list is empty?
# For example, if passed the following:
# a = []
# How do I check to see if a is empty?
# pythonlist
# Ray
# 190k
# asked Sep 10, 2008 at 6:20
# --------------------------------------------------
# 3227
# votes
# 11
# answers
# 3.1m
# views
# Manually raising (throwing) an exception in Python
# How do I raise an exception in Python so that it can later be caught via an except block?
# pythonexception
# TIMEX
# 265k
# asked Jan 12, 2010 at 21:07
# --------------------------------------------------
# 3218
# votes
# 13
# answers
# 3.7m
# views
# How do I make a time delay? [duplicate]
# How do I put a time delay in a Python script?
# pythondelaysleeptimedelay
# user46646
# 156k
# asked Feb 4, 2009 at 7:04
# --------------------------------------------------
# 3218
# votes
# 7
# answers
# 2.7m
# views
# Understanding Python super() with __init__() methods [duplicate]
# Why is super() used?
# Is there a difference between using Base.__init__ and super().__init__?
# class Base(object):
# def __init__(self):
# print "Base created"
# class ChildA(...
# pythonclassoopinheritancesuper
# Mizipzor
# 51.7k
# asked Feb 23, 2009 at 0:30
# --------------------------------------------------
# 3201
# votes
# 15
# answers
# 6.0m
# views
# How do I change the size of figures drawn with Matplotlib?
# How do I change the size of figure drawn with Matplotlib?
# pythonpandasmatplotlibseabornfigsize
# tatwright
# 38k
# asked Dec 1, 2008 at 21:24
# --------------------------------------------------
# 3185
# votes
# 65
# answers
# 2.5m
# views
# How do I print colored text to the terminal?
# How do I output colored text to the terminal in Python?
# pythonterminaloutputansi-colors
# aboSamoor
# 32.1k
# asked Nov 13, 2008 at 18:58
# --------------------------------------------------
# 3156
# votes
# 22
# answers
# 657k
# views
# How do I make function decorators and chain them together?
# How do I make two decorators in Python that would do the following?
# @make_bold
# @make_italic
# def say():
# return "Hello"
# Calling say() should return:
# "<b><i>Hello</i>&...
# pythonfunctiondecoratorpython-decoratorschain
# Imran
# 89k
# asked Apr 11, 2009 at 7:05
# --------------------------------------------------
# 3111
# votes
# 20
# answers
# 3.3m
# views
# What is the difference between Python's list methods append and extend?
# What's the difference between the list methods append() and extend()?
# pythonlistdata-structuresappendextend
# Claudiu
# 226k
# asked Oct 31, 2008 at 5:55
# --------------------------------------------------
# 3111
# votes
# 70
# answers
# 1.7m
# views
# How do I split a list into equally-sized chunks?
# How do I split a list of arbitrary length into equal sized chunks?
# See also: How to iterate over a list in chunks.
# To chunk strings, see Split string every nth character?.
# pythonlistsplitchunks
# jespern
# 32.9k
# asked Nov 23, 2008 at 12:15
# --------------------------------------------------
# 3010
# votes
# 12
# answers
# 364k
# views
# Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# It is my understanding that the range() function, which is actually an object type in Python 3, generates its contents on the fly, similar to a generator.
# This being the case, I would have expected ...
# pythonperformancepython-3.xrangepython-internals
# Rick
# 43.9k
# asked May 6, 2015 at 15:32
# --------------------------------------------------
# 2995
# votes
# 13
# answers
# 4.8m
# views
# Find the current directory and file's directory [duplicate]
# How do I determine:
# the current directory (where I was in the shell when I ran the Python script), and
# where the Python file I am executing is?
# pythondirectory
# John Howard
# 62.4k
# asked Feb 28, 2011 at 1:51
# --------------------------------------------------
# 2957
# votes
# 33
# answers
# 6.4m
# views
# Renaming column names in Pandas
# I want to change the column labels of a Pandas DataFrame from
# ['$a', '$b', '$c', '$d', '$e']
# to
# ['a', 'b', 'c', 'd', 'e']
# pythonpandasreplacedataframerename
# user1504276
# 29.7k
# asked Jul 5, 2012 at 14:21
# --------------------------------------------------
# 2954
# votes
# 26
# answers
# 4.6m
# views
# Convert string "Jun 1 2005 1:33PM" into datetime
# I have a huge list of datetime strings like the following
# ["Jun 1 2005 1:33PM", "Aug 28 1999 12:00AM"]
# How do I convert them into datetime objects?
# pythondatetime
# Oli
# 238k
# asked Jan 21, 2009 at 18:00
# --------------------------------------------------
# 2890
# votes
# 11
# answers
# 2.7m
# views
# How can I remove a key from a Python dictionary?
# I want to remove a key from a dictionary if it is present. I currently use this code:
# if key in my_dict:
# del my_dict[key]
# Without the if statement, the code will raise KeyError if the key is not ...
# pythondictionaryunset
# Tony
# 37.4k
# asked Jun 30, 2012 at 20:27
# --------------------------------------------------
# 2776
# votes
# 22
# answers
# 1.4m
# views
# How to sort a list of dictionaries by a value of the dictionary in Python?
# How do I sort a list of dictionaries by a specific key's value? Given:
# [{'name': 'Homer', 'age': 39}, {'name': 'Bart', 'age': 10}]
# When sorted by name, it should become:
# [{'name': 'Bart', 'age': 10}, ...
# pythonlistsortingdictionarydata-structures
# Community wiki
# 15 revs, 10 users 43%masi
# --------------------------------------------------
# 2775
# votes
# 60
# answers
# 1.9m
# views
# How to upgrade all Python packages with pip
# Is it possible to upgrade all Python packages at one time with pip?
# Note: that there is a feature request for this on the official issue tracker.
# pythonpip
# thedjpetersen
# 28.5k
# asked Apr 27, 2010 at 9:23
# --------------------------------------------------

# %% [markdown]
# ## Scraping only needed data

# %%
import requests
from bs4 import BeautifulSoup

# Load the URL
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'python'
query_filter = 'Votes'
url = f"{base_url}{tag}?tab={query_filter}"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all elements with the class 's-post-summary' or 'js-post-summary'
    post_summaries = soup.find_all(class_=['s-post-summary'])
    
    # Initialize data list
    data = []
    
    # Iterate over each post summary
    for post_summary in post_summaries:
        # Extract the question title
        question_title = post_summary.find(class_='s-post-summary--content-title').text.strip()
        
        # Extract the number of votes
        votes = post_summary.find(class_='s-post-summary--stats-item-number').text.strip()

        # Extract tags
        tags = post_summary.find(class_='tags').text.strip()
        
        post_data = {
            'question_title': question_title,
            'votes': votes,
            'tags': tags
        }

        data.append(post_data)
        
    # Print the extracted data
    for item in data:
        print("Question:", item['question_title'])
        print("Votes:", item['votes'])
        print("Tags:", item['tags'])
        print('-' * 50)
# Out:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------

# %%
# data[0]

# %% [markdown]
# ## Changing tags and scraping

# %%
import requests
from bs4 import BeautifulSoup

# Load the URL
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'javascript'
query_filter = 'Votes'
url = f"{base_url}{tag}?tab={query_filter}"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all elements with the class 's-post-summary' or 'js-post-summary'
    post_summaries = soup.find_all(class_=['s-post-summary'])
    
    # Initialize data list
    data1 = []
    
    # Iterate over each post summary
    for post_summary in post_summaries:
        # Extract the question title
        question_title = post_summary.find(class_='s-post-summary--content-title').text.strip()
        
        # Extract the number of votes
        votes = post_summary.find(class_='s-post-summary--stats-item-number').text.strip()

        # Extract tags
        tags = post_summary.find(class_='tags').text.strip()
        
        post_data = {
            'question_title': question_title,
            'votes': votes,
            'tags': tags
        }

        data1.append(post_data)
        
    # Print the extracted data
    for item in data1:
        print("Question:", item['question_title'])
        print("Votes:", item['votes'])
        print("Tags:", item['tags'])
        print('-' * 50)
# Out:
# Question: How can I remove a specific item from an array in JavaScript?
# Votes: 11875
# Tags: javascriptarrays
# --------------------------------------------------
# Question: How do I check if an element is hidden in jQuery?
# Votes: 8672
# Tags: javascriptjquerydomvisibilitydisplay
# --------------------------------------------------
# Question: What does "use strict" do in JavaScript, and what is the reasoning behind it?
# Votes: 8475
# Tags: javascriptsyntaxjslintuse-strict
# --------------------------------------------------
# Question: How do I redirect to another webpage?
# Votes: 7701
# Tags: javascriptjqueryredirect
# --------------------------------------------------
# Question: var functionName = function() {} vs function functionName() {}
# Votes: 7627
# Tags: javascriptfunctionmethodssyntax
# --------------------------------------------------
# Question: How do JavaScript closures work?
# Votes: 7619
# Tags: javascriptfunctionvariablesscopeclosures
# --------------------------------------------------
# Question: How do I remove a property from a JavaScript object?
# Votes: 7476
# Tags: javascriptobjectproperties
# --------------------------------------------------
# Question: How to check whether a string contains a substring in JavaScript?
# Votes: 7406
# Tags: javascriptstringsubstringstring-matching
# --------------------------------------------------
# Question: How do I return the response from an asynchronous call?
# Votes: 6688
# Tags: javascriptajaxasynchronous
# --------------------------------------------------
# Question: How do I include a JavaScript file in another JavaScript file?
# Votes: 6310
# Tags: javascriptfileimportinclude
# --------------------------------------------------
# Question: What is the difference between "let" and "var"?
# Votes: 6257
# Tags: javascriptscopeecmascript-6varlet
# --------------------------------------------------
# Question: Loop (for each) over an array in JavaScript
# Votes: 5684
# Tags: javascriptarraysloopsforeachiteration
# --------------------------------------------------
# Question: Which equals operator (== vs ===) should be used in JavaScript comparisons?
# Votes: 5647
# Tags: javascriptoperatorsequalityequality-operatoridentity-operator
# --------------------------------------------------
# Question: How can I validate an email address in JavaScript?
# Votes: 5474
# Tags: javascripthtmlregexemail-validation
# --------------------------------------------------
# Question: How do I replace all occurrences of a string in JavaScript?
# Votes: 5460
# Tags: javascriptstringreplace
# --------------------------------------------------
# Question: How do I create a GUID / UUID?
# Votes: 5368
# Tags: javascriptguiduuid
# --------------------------------------------------
# Question: How do I make the first letter of a string uppercase in JavaScript?
# Votes: 5205
# Tags: javascriptstring
# --------------------------------------------------
# Question: How do I check whether a checkbox is checked in jQuery?
# Votes: 5186
# Tags: javascriptjqueryhtmlcheckbox
# --------------------------------------------------
# Question: What is the most efficient way to deep clone an object in JavaScript?
# Votes: 5166
# Tags: javascriptobjectclone
# --------------------------------------------------
# Question: How do I check if an array includes a value in JavaScript?
# Votes: 4926
# Tags: javascriptarraysalgorithmtime-complexityjavascript-objects
# --------------------------------------------------
# Question: How do I get a timestamp in JavaScript?
# Votes: 4831
# Tags: javascriptdatetimetimestampdate-arithmetic
# --------------------------------------------------
# Question: Setting "checked" for a checkbox with jQuery
# Votes: 4586
# Tags: javascriptjquerycheckboxselectedchecked
# --------------------------------------------------
# Question: "Thinking in AngularJS" if I have a jQuery background? [closed]
# Votes: 4506
# Tags: javascriptjqueryangularjs
# --------------------------------------------------
# Question: Why does Google prepend while(1); to their JSON responses?
# Votes: 4485
# Tags: javascriptjsonajaxsecurity
# --------------------------------------------------
# Question: Which "href" value should I use for JavaScript links, "#" or "javascript:void(0)"?
# Votes: 4432
# Tags: javascripthtmlperformanceoptimizationhref
# --------------------------------------------------
# Question: How do I copy to the clipboard in JavaScript?
# Votes: 4346
# Tags: javascriptclipboardcopy-paste
# --------------------------------------------------
# Question: How to insert an item into an array at a specific index?
# Votes: 4249
# Tags: javascriptarrays
# --------------------------------------------------
# Question: How to round to at most 2 decimal places, if necessary
# Votes: 4174
# Tags: javascriptroundingdecimal-point
# --------------------------------------------------
# Question: What is the !! (not not) operator in JavaScript?
# Votes: 4156
# Tags: javascriptoperators
# --------------------------------------------------
# Question: Sort array of objects by string property value
# Votes: 4129
# Tags: javascriptarrayssortingcomparisonarray-of-dict
# --------------------------------------------------
# Question: Checking if a key exists in a JavaScript object?
# Votes: 4050
# Tags: javascriptarraysobject
# --------------------------------------------------
# Question: Loop through an array in JavaScript
# Votes: 4010
# Tags: javascriptarraysloopsfor-loop
# --------------------------------------------------
# Question: How do I check for an empty/undefined/null string in JavaScript?
# Votes: 4006
# Tags: javascriptnullis-empty
# --------------------------------------------------
# Question: How do I test for an empty JavaScript object?
# Votes: 3892
# Tags: javascriptjavascript-objects
# --------------------------------------------------
# Question: What is the JavaScript version of sleep()?
# Votes: 3766
# Tags: javascriptsleep
# --------------------------------------------------
# Question: Get the current URL with JavaScript?
# Votes: 3750
# Tags: javascripturl
# --------------------------------------------------
# Question: How do I correctly clone a JavaScript object?
# Votes: 3743
# Tags: javascriptclonejavascript-objects
# --------------------------------------------------
# Question: How do I loop through or enumerate a JavaScript object?
# Votes: 3578
# Tags: javascriptloopsfor-loopeach
# --------------------------------------------------
# Question: How can I convert a string to boolean in JavaScript?
# Votes: 3519
# Tags: javascriptboolean-expressionboolean-operationsstring-conversion
# --------------------------------------------------
# Question: How do I format a date in JavaScript?
# Votes: 3499
# Tags: javascriptdatedate-formatting
# --------------------------------------------------
# Question: What is the difference between call and apply?
# Votes: 3476
# Tags: javascriptfunctionperformance
# --------------------------------------------------
# Question: Creating multiline strings in JavaScript
# Votes: 3451
# Tags: javascriptstringmultilineheredoc
# --------------------------------------------------
# Question: pretty-print JSON using JavaScript
# Votes: 3424
# Tags: javascriptjsonpretty-print
# --------------------------------------------------
# Question: How can I change an element's class with JavaScript?
# Votes: 3416
# Tags: javascripthtmldom
# --------------------------------------------------
# Question: How can I check if an object is an array? [duplicate]
# Votes: 3327
# Tags: javascriptarraysjavascript-objects
# --------------------------------------------------
# Question: Why does my JavaScript code receive a "No 'Access-Control-Allow-Origin' header is present on the requested resource" error, while Postman does not?
# Votes: 3306
# Tags: javascriptjquerycorspostmansame-origin-policy
# --------------------------------------------------
# Question: How can I merge properties of two JavaScript objects?
# Votes: 3287
# Tags: javascriptjavascript-objects
# --------------------------------------------------
# Question: event.preventDefault() vs. return false
# Votes: 3248
# Tags: javascriptjqueryevent-handlingdom-eventsevent-propagation
# --------------------------------------------------
# Question: JavaScript closure inside loops – simple practical example
# Votes: 3240
# Tags: javascriptloopsclosures
# --------------------------------------------------
# Question: Detecting an undefined object property
# Votes: 3218
# Tags: javascriptobjectundefinedobject-property
# --------------------------------------------------

# %%
# data1[0]

# %% [markdown]
# ## Scraping multiple pages

# %%
import requests
from bs4 import BeautifulSoup

# Load the URL
base_url = 'https://stackoverflow.com/questions/tagged/'
tag = 'python'
query_filter = 'Votes'
url = f"{base_url}{tag}?tab={query_filter}"

# Function to scrape a single page
def scrape_page(url):
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all elements with the class 's-post-summary' or 'js-post-summary'
        post_summaries = soup.find_all(class_=['s-post-summary'])
        
        # Initialize data list
        data2 = []
        
        # Iterate over each post summary
        for post_summary in post_summaries:
            # Extract the question title
            question_title = post_summary.find(class_='s-post-summary--content-title').text.strip()
            
            # Extract the number of votes
            votes = post_summary.find(class_='s-post-summary--stats-item-number').text.strip()

            # Extract tags
            tags = post_summary.find(class_='tags').text.strip()
            
            post_data = {
                'question_title': question_title,
                'votes': votes,
                'tags': tags
            }

            data2.append(post_data)
        
        return data2

# Scrape multiple pages
total_pages = 5  # Number of pages to scrape
for page_num in range(1, total_pages + 1):
    url = url.format(base_url, tag, query_filter, page_num)
    page_data = scrape_page(url)
    
    # Print the extracted data for the current page
    print(f"Page {page_num}:")
    for item in page_data:
        print("Question:", item['question_title'])
        print("Votes:", item['votes'])
        print("Tags:", item['tags'])
        print('-' * 50)
# Out:
# Page 1:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------
# Page 2:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------
# Page 3:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------
# Page 4:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------
# Page 5:
# Question: What does the "yield" keyword do in Python?
# Votes: 12878
# Tags: pythoniteratorgeneratoryield
# --------------------------------------------------
# Question: What does if __name__ == "__main__": do?
# Votes: 8196
# Tags: pythonnamespacesprogram-entry-pointpython-moduleidioms
# --------------------------------------------------
# Question: Does Python have a ternary conditional operator?
# Votes: 7901
# Tags: pythonoperatorsconditional-operator
# --------------------------------------------------
# Question: What are metaclasses in Python?
# Votes: 7364
# Tags: pythonoopmetaclasspython-classpython-datamodel
# --------------------------------------------------
# Question: How do I check whether a file exists without exceptions?
# Votes: 7123
# Tags: pythonfilefile-exists
# --------------------------------------------------
# Question: How do I merge two dictionaries in a single expression in Python?
# Votes: 6917
# Tags: pythondictionarymerge
# --------------------------------------------------
# Question: How do I execute a program or call a system command?
# Votes: 6111
# Tags: pythonshellterminalsubprocesscommand
# --------------------------------------------------
# Question: How do I create a directory, and any missing parent directories?
# Votes: 5643
# Tags: pythonexceptionpathdirectoryoperating-system
# --------------------------------------------------
# Question: How to access the index value in a 'for' loop?
# Votes: 5421
# Tags: pythonloopslist
# --------------------------------------------------
# Question: How do I make a flat list out of a list of lists?
# Votes: 5317
# Tags: pythonlistmultidimensional-arrayflatten
# --------------------------------------------------
# Question: What is the difference between @staticmethod and @classmethod in Python?
# Votes: 4641
# Tags: pythonoopstatic-methodspython-decoratorsclass-method
# --------------------------------------------------
# Question: How slicing in Python works
# Votes: 4583
# Tags: pythonslicesequence
# --------------------------------------------------
# Question: How to find the index for a given item in a list?
# Votes: 4385
# Tags: pythonlistindexing
# --------------------------------------------------
# Question: Iterating over dictionaries using 'for' loops
# Votes: 4304
# Tags: pythondictionary
# --------------------------------------------------
# Question: How can I iterate over rows in a Pandas DataFrame?
# Votes: 4075
# Tags: pythonpandasdataframeloops
# --------------------------------------------------
# Question: How to use a global variable in a function?
# Votes: 3948
# Tags: pythonglobal-variablesscope
# --------------------------------------------------
# Question: How do I get the current time in Python?
# Votes: 3853
# Tags: pythondatetimetime
# --------------------------------------------------
# Question: How to catch multiple exceptions in one line? (in the "except" block)
# Votes: 3823
# Tags: pythonexception
# --------------------------------------------------
# Question: How to copy files
# Votes: 3793
# Tags: pythonfilecopyfilesystemsfile-copying
# --------------------------------------------------
# Question: Convert bytes to a string in Python 3
# Votes: 3751
# Tags: pythonstringpython-3.x
# --------------------------------------------------
# Question: What is __init__.py for?
# Votes: 3730
# Tags: pythonmodulepackagepython-packaging
# --------------------------------------------------
# Question: What is the difference between __str__ and __repr__?
# Votes: 3689
# Tags: pythonmagic-methodsrepr
# --------------------------------------------------
# Question: Does Python have a string 'contains' substring method?
# Votes: 3587
# Tags: pythonstringsubstringcontains
# --------------------------------------------------
# Question: How can I add new keys to a dictionary?
# Votes: 3523
# Tags: pythondictionarylookup
# --------------------------------------------------
# Question: How do I select rows from a DataFrame based on column values?
# Votes: 3504
# Tags: pythonpandasdataframe
# --------------------------------------------------
# Question: How do I list all files of a directory?
# Votes: 3466
# Tags: pythondirectory
# --------------------------------------------------
# Question: How do I sort a dictionary by value?
# Votes: 3413
# Tags: pythonsortingdictionary
# --------------------------------------------------
# Question: "Least Astonishment" and the Mutable Default Argument
# Votes: 3413
# Tags: pythonlanguage-designdefault-parametersleast-astonishment
# --------------------------------------------------
# Question: What does ** (double star/asterisk) and * (star/asterisk) do for parameters?
# Votes: 3379
# Tags: pythonsyntaxparameter-passingvariadic-functionsargument-unpacking
# --------------------------------------------------
# Question: How can I delete a file or folder in Python?
# Votes: 3376
# Tags: pythonfile-iodirectorydelete-file
# --------------------------------------------------
# Question: How do I pass a variable by reference?
# Votes: 3295
# Tags: pythonreferenceparameter-passingpass-by-reference
# --------------------------------------------------
# Question: How do I clone a list so that it doesn't change unexpectedly after assignment?
# Votes: 3289
# Tags: pythonlistclonemutable
# --------------------------------------------------
# Question: How can I access environment variables in Python?
# Votes: 3243
# Tags: pythonenvironment-variables
# --------------------------------------------------
# Question: How do I concatenate two lists in Python?
# Votes: 3238
# Tags: pythonlistconcatenation
# --------------------------------------------------
# Question: How do I check if a list is empty?
# Votes: 3227
# Tags: pythonlist
# --------------------------------------------------
# Question: Manually raising (throwing) an exception in Python
# Votes: 3227
# Tags: pythonexception
# --------------------------------------------------
# Question: How do I make a time delay? [duplicate]
# Votes: 3218
# Tags: pythondelaysleeptimedelay
# --------------------------------------------------
# Question: Understanding Python super() with __init__() methods [duplicate]
# Votes: 3218
# Tags: pythonclassoopinheritancesuper
# --------------------------------------------------
# Question: How do I change the size of figures drawn with Matplotlib?
# Votes: 3201
# Tags: pythonpandasmatplotlibseabornfigsize
# --------------------------------------------------
# Question: How do I print colored text to the terminal?
# Votes: 3185
# Tags: pythonterminaloutputansi-colors
# --------------------------------------------------
# Question: How do I make function decorators and chain them together?
# Votes: 3156
# Tags: pythonfunctiondecoratorpython-decoratorschain
# --------------------------------------------------
# Question: What is the difference between Python's list methods append and extend?
# Votes: 3111
# Tags: pythonlistdata-structuresappendextend
# --------------------------------------------------
# Question: How do I split a list into equally-sized chunks?
# Votes: 3111
# Tags: pythonlistsplitchunks
# --------------------------------------------------
# Question: Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?
# Votes: 3010
# Tags: pythonperformancepython-3.xrangepython-internals
# --------------------------------------------------
# Question: Find the current directory and file's directory [duplicate]
# Votes: 2995
# Tags: pythondirectory
# --------------------------------------------------
# Question: Renaming column names in Pandas
# Votes: 2957
# Tags: pythonpandasreplacedataframerename
# --------------------------------------------------
# Question: Convert string "Jun 1 2005 1:33PM" into datetime
# Votes: 2954
# Tags: pythondatetime
# --------------------------------------------------
# Question: How can I remove a key from a Python dictionary?
# Votes: 2890
# Tags: pythondictionaryunset
# --------------------------------------------------
# Question: How to sort a list of dictionaries by a value of the dictionary in Python?
# Votes: 2776
# Tags: pythonlistsortingdictionarydata-structures
# --------------------------------------------------
# Question: How to upgrade all Python packages with pip
# Votes: 2775
# Tags: pythonpip
# --------------------------------------------------

# %%
df = pd.DataFrame(page_data)
df.head(112)
# Out:
#                                        question_title  votes  \
# 0         What does the "yield" keyword do in Python?  12878
# 1            What does if __name__ == "__main__": do?   8196
# 2    Does Python have a ternary conditional operator?   7901
# 3                     What are metaclasses in Python?   7364
# 4   How do I check whether a file exists without e...   7123
# 5   How do I merge two dictionaries in a single ex...   6917
# 6   How do I execute a program or call a system co...   6111
# 7   How do I create a directory, and any missing p...   5643
# 8      How to access the index value in a 'for' loop?   5421
# 9   How do I make a flat list out of a list of lists?   5317
# 10  What is the difference between @staticmethod a...   4641
# 11                        How slicing in Python works   4583
# 12  How to find the index for a given item in a list?   4385
# 13      Iterating over dictionaries using 'for' loops   4304
# 14  How can I iterate over rows in a Pandas DataFr...   4075
# 15        How to use a global variable in a function?   3948
# 16           How do I get the current time in Python?   3853
# 17  How to catch multiple exceptions in one line? ...   3823
# 18                                  How to copy files   3793
# 19              Convert bytes to a string in Python 3   3751
# 20                           What is __init__.py for?   3730
# 21  What is the difference between __str__ and __r...   3689
# 22  Does Python have a string 'contains' substring...   3587
# 23            How can I add new keys to a dictionary?   3523
# 24  How do I select rows from a DataFrame based on...   3504
# 25            How do I list all files of a directory?   3466
# 26               How do I sort a dictionary by value?   3413
# 27  "Least Astonishment" and the Mutable Default A...   3413
# 28  What does ** (double star/asterisk) and * (sta...   3379
# 29       How can I delete a file or folder in Python?   3376
# 30             How do I pass a variable by reference?   3295
# 31  How do I clone a list so that it doesn't chang...   3289
# 32  How can I access environment variables in Python?   3243
# 33          How do I concatenate two lists in Python?   3238
# 34                 How do I check if a list is empty?   3227
# 35  Manually raising (throwing) an exception in Py...   3227
# 36            How do I make a time delay? [duplicate]   3218
# 37  Understanding Python super() with __init__() m...   3218
# 38  How do I change the size of figures drawn with...   3201
# 39       How do I print colored text to the terminal?   3185
# 40  How do I make function decorators and chain th...   3156
# 41  What is the difference between Python's list m...   3111
# 42   How do I split a list into equally-sized chunks?   3111
# 43  Why is "1000000000000000 in range(100000000000...   3010
# 44  Find the current directory and file's director...   2995
# 45                    Renaming column names in Pandas   2957
# 46   Convert string "Jun 1 2005 1:33PM" into datetime   2954
# 47   How can I remove a key from a Python dictionary?   2890
# 48  How to sort a list of dictionaries by a value ...   2776
# 49        How to upgrade all Python packages with pip   2775
#
#                                                  tags
# 0                        pythoniteratorgeneratoryield
# 1   pythonnamespacesprogram-entry-pointpython-modu...
# 2                 pythonoperatorsconditional-operator
# 3      pythonoopmetaclasspython-classpython-datamodel
# 4                               pythonfilefile-exists
# 5                               pythondictionarymerge
# 6                pythonshellterminalsubprocesscommand
# 7        pythonexceptionpathdirectoryoperating-system
# 8                                     pythonloopslist
# 9             pythonlistmultidimensional-arrayflatten
# 10  pythonoopstatic-methodspython-decoratorsclass-...
# 11                                pythonslicesequence
# 12                                 pythonlistindexing
# 13                                   pythondictionary
# 14                         pythonpandasdataframeloops
# 15                        pythonglobal-variablesscope
# 16                                 pythondatetimetime
# 17                                    pythonexception
# 18              pythonfilecopyfilesystemsfile-copying
# 19                             pythonstringpython-3.x
# 20                pythonmodulepackagepython-packaging
# 21                            pythonmagic-methodsrepr
# 22                      pythonstringsubstringcontains
# 23                             pythondictionarylookup
# 24                              pythonpandasdataframe
# 25                                    pythondirectory
# 26                            pythonsortingdictionary
# 27  pythonlanguage-designdefault-parametersleast-a...
# 28  pythonsyntaxparameter-passingvariadic-function...
# 29                  pythonfile-iodirectorydelete-file
# 30  pythonreferenceparameter-passingpass-by-reference
# 31                             pythonlistclonemutable
# 32                        pythonenvironment-variables
# 33                            pythonlistconcatenation
# 34                                         pythonlist
# 35                                    pythonexception
# 36                          pythondelaysleeptimedelay
# 37                     pythonclassoopinheritancesuper
# 38               pythonpandasmatplotlibseabornfigsize
# 39                    pythonterminaloutputansi-colors
# 40      pythonfunctiondecoratorpython-decoratorschain
# 41              pythonlistdata-structuresappendextend
# 42                              pythonlistsplitchunks
# 43   pythonperformancepython-3.xrangepython-internals
# 44                                    pythondirectory
# 45                 pythonpandasreplacedataframerename
# 46                                     pythondatetime
# 47                              pythondictionaryunset
# 48         pythonlistsortingdictionarydata-structures
# 49                                          pythonpip

# %%
df.shape
# Out:
# (50, 3)

# %%
df.to_csv("python.csv", index=False)
